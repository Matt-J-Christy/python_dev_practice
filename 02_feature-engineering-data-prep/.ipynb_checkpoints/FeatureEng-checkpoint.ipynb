# %% [markdown]
# ## Feature Engineering for Modeling

# %% [markdown]
# ### Steps to feature engineer:
#     1. create candidate features
#         * 4 week prior avgerage: points, yds, touches, touchdowns, fumbles, qbr
#         * opp win record, opp avg def pts allowed
#         * isStarter, isHurt
#     2. create incemental refresh schedule
#     3. write final data set to Google Drive

# %%
#importing various libraries 
import gspread 
#Service client credential from oauth2client
from oauth2client.service_account import ServiceAccountCredentials
# Print nicely
import pprint
#Create scope
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
#create some credential using that scope and content of startup_funding.json
creds = ServiceAccountCredentials.from_json_keyfile_name('../quickstart/g_sheet_creds.json',scope)
#create gspread authorize using that credential
client = gspread.authorize(creds)
my_email = 'matthewjchristy66@gmail.com'

# %%
#data manipulation 
import pandas as pd 
import numpy as np

# %%
def read_file(sheet_name):
    out = client.open(sheet_name).sheet1
    out = out.get_all_values()
    out = pd.DataFrame(out, columns = out.pop(0))
    return(out)

# %%
#grabbing data for modeling 
passing = read_file(sheet_name = 'passing_processed_step1')
rush = read_file(sheet_name= 'rushing_processed_step1')
rec = read_file(sheet_name = 'receiving_processed_step1')

# %%
passing.head()
# Out:
#                Name Week Team     Opp     Score Comp Att  Yds TD Int Sck FUM  \
# 0       Andy Dalton    1  CIN   @ SEA  L 20-21    35  51  418  2   0   5   2
# 1      Dak Prescott    1  DAL  vs NYG  W 35-17    25  32  405  4   0   0   0
# 2  Matthew Stafford    1  DET   @ ARI  T 27-27    27  45  385  3   0   3   1
# 3       Case Keenum    1  WAS   @ PHI  L 27-32    30  44  380  3   0   1   0
# 4   Patrick Mahomes    1   KC   @ JAX  W 40-26    25  33  378  3   0   0   0
#
#     Rate 300yd_flag passing_fantasy_pts
# 0  106.5          1               24.72
# 1  158.3          1                32.2
# 2    110          1                27.4
# 3  117.6          1                27.2
# 4  143.2          1               27.12

# %%
rush.head()
# Out:
#                   Name Week Team     Opp     Score Att  Yds   Avg TD FUM  \
# 0          Marlon Mack    1  IND   @ LAC  L 24-30   25  174   7.0  1   0
# 1  Christian McCaffrey    1  CAR   vs LA  L 27-30   19  128   6.7  2   0
# 2       Saquon Barkley    1  NYG   @ DAL  L 17-35   11  120  10.9  0   0
# 3          Dalvin Cook    1  MIN  vs ATL  W 28-12   21  111   5.3  2   0
# 4          Mark Ingram    1  BAL   @ MIA  W 59-10   14  107   7.6  2   0
#
#   100yd_flag rush_fantasy_pts
# 0          1             23.4
# 1          1             24.8
# 2          1               12
# 3          1             23.1
# 4          1             22.7

# %%
rec.head()
# Out:
#              Name Week Team     Opp     Score Rec  Yds   Avg TD FUM  \
# 0   Sammy Watkins    1   KC   @ JAX  W 40-26    9  198  22.0  3   0
# 1  Michael Gallup    1  DAL  vs NYG  W 35-17    7  158  22.6  0   0
# 2       John Ross    1  CIN   @ SEA  L 20-21    7  158  22.6  2   0
# 3  DeSean Jackson    1  PHI  vs WAS  W 32-27    8  154  19.2  2   0
# 4  Marquise Brown    1  BAL   @ MIA  W 59-10    4  147  36.8  2   0
#
#   100yd_flag rec_fantasy_pts
# 0          1            37.8
# 1          1            15.8
# 2          1            27.8
# 3          1            27.4
# 4          1            26.7

# %%
#creating a moving avg function 
def move_avg(df, smooth_col, group_vals, window):
    l_mean = lambda x: x.rolling(window, 1).mean()
    out = df.groupby(group_vals)[smooth_col].transform(l_mean)
    return(out)

# %%
#light cleaning 
pf = ['Comp', 'Att', 'Yds', 'TD', 'Int', 'Sck', 'FUM', 'Rate', 'passing_fantasy_pts']
rrf = ['Yds', 'TD', 'FUM']
passing[pf] = passing[pf].astype(float)
rush[rrf] = rush[rrf].astype(float)
rec[rrf] = rec[rrf].astype(float)
rec['rec_fantasy_pts'] = rec['rec_fantasy_pts'].astype(float)
rush['rush_fantasy_pts'] = rush['rush_fantasy_pts'].astype(float)

# %% [markdown]
# ### Passing Feature Eng

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

series = passing.passing_fantasy_pts

# %%
plot_acf(series, title = 'Passing Pts No Lag')
plt.show()

# %%
plot_pacf(series, title = 'pacf no lag')
plt.show()

# %%
cols = ['Yds', 'TD', 'Int', 'Rate', 'passing_fantasy_pts']
lag3 = ['lag3_' + ''.join(x) for x in cols]
lag1 = ['lag1_' + ''.join(x) for x in cols]

# %%
passing[lag3] = move_avg(df=passing, smooth_col=cols, group_vals='Name', window=3)
passing[lag1] = move_avg(df = passing, smooth_col=cols, group_vals='Name', window=1)

# %%
passing['yds_ratio'] = passing.lag3_Yds/passing.lag1_Yds
passing['rate_ratio'] = passing.lag3_Rate/passing.lag1_Rate
passing['fantasy_pts_ratio'] = passing.lag3_passing_fantasy_pts/passing.lag1_passing_fantasy_pts

# %%
passing.loc[passing.Name == 'Lamar Jackson', :]
# Out:
#               Name Week Team     Opp     Score  Comp   Att    Yds   TD  Int  \
# 8    Lamar Jackson    1  BAL   @ MIA  W 59-10   17.0  20.0  324.0  5.0  0.0
# 49   Lamar Jackson    2  BAL  vs ARI  W 23-17   24.0  37.0  272.0  2.0  0.0
# 89   Lamar Jackson    3  BAL    @ KC  L 28-33   22.0  43.0  267.0  0.0  0.0
# 120  Lamar Jackson    4  BAL  vs CLE  L 25-40   24.0  34.0  247.0  3.0  2.0
# 172  Lamar Jackson    5  BAL   @ PIT  W 26-23   19.0  28.0  161.0  1.0  3.0
# 204  Lamar Jackson    6  BAL  vs CIN  W 23-17   21.0  33.0  236.0  0.0  0.0
# 241  Lamar Jackson    7  BAL   @ SEA  W 30-16    9.0  20.0  143.0  0.0  0.0
# 310  Lamar Jackson    9  BAL   vs NE  W 37-20   17.0  23.0  163.0  1.0  0.0
# 333  Lamar Jackson   10  BAL   @ CIN  W 49-13   15.0  17.0  223.0  3.0  0.0
# 364  Lamar Jackson   11  BAL  vs HOU   W 41-7   17.0  24.0  222.0  4.0  0.0
# 407  Lamar Jackson   12  BAL    @ LA   W 45-6   15.0  20.0  169.0  5.0  0.0
# 452  Lamar Jackson   13  BAL   vs SF  W 20-17   14.0  23.0  105.0  1.0  0.0
# 491  Lamar Jackson   14  BAL   @ BUF  W 24-17   16.0  25.0  145.0  3.0  1.0
# 519  Lamar Jackson   15  BAL  vs NYJ  W 42-21   15.0  23.0  212.0  5.0  0.0
# 554  Lamar Jackson   16  BAL   @ CLE  W 31-15   20.0  31.0  238.0  3.0  0.0
#
#      ...   lag3_Rate  lag3_passing_fantasy_pts  lag1_Yds lag1_TD  lag1_Int  \
# 8    ...  158.300000                 32.960000     324.0     5.0       0.0
# 49   ...  131.550000                 25.920000     272.0     2.0       0.0
# 89   ...  111.233333                 20.840000     267.0     0.0       0.0
# 120  ...   90.500000                 17.146667     247.0     3.0       2.0
# 172  ...   73.866667                 14.333333     161.0     1.0       3.0
# 204  ...   78.633333                 13.920000     236.0     0.0       0.0
# 241  ...   69.733333                  8.533333     143.0     0.0       0.0
# 310  ...   87.333333                  8.560000     163.0     1.0       0.0
# 333  ...  111.800000                 12.386667     223.0     3.0       0.0
# 364  ...  135.066667                 18.773333     222.0     4.0       0.0
# 407  ...  145.633333                 24.186667     169.0     5.0       0.0
# 452  ...  121.633333                 19.946667     105.0     1.0       0.0
# 491  ...  109.400000                 17.586667     145.0     3.0       1.0
# 519  ...  107.733333                 18.160000     212.0     5.0       0.0
# 554  ...  119.000000                 22.600000     238.0     3.0       0.0
#
#      lag1_Rate  lag1_passing_fantasy_pts  yds_ratio  rate_ratio  \
# 8        158.3                     32.96   1.000000    1.000000
# 49       104.8                     18.88   1.095588    1.255248
# 89        70.6                     10.68   1.077403    1.575543
# 120       96.1                     21.88   1.060729    0.941727
# 172       54.9                     10.44   1.397516    1.345477
# 204       84.9                      9.44   0.909605    0.926188
# 241       69.4                      5.72   1.258741    1.004803
# 310      107.7                     10.52   1.108384    0.810894
# 333      158.3                     20.92   0.790732    0.706254
# 364      139.2                     24.88   0.912913    0.970307
# 407      139.4                     26.76   1.211045    1.044715
# 452       86.3                      8.20   1.574603    1.409424
# 491      102.5                     17.80   0.963218    1.067317
# 519      134.4                     28.48   0.726415    0.801587
# 554      120.1                     21.52   0.833333    0.990841
#
#      fantasy_pts_ratio
# 8             1.000000
# 49            1.372881
# 89            1.951311
# 120           0.783668
# 172           1.372925
# 204           1.474576
# 241           1.491841
# 310           0.813688
# 333           0.592097
# 364           0.754555
# 407           0.903837
# 452           2.432520
# 491           0.988015
# 519           0.637640
# 554           1.050186
#
# [15 rows x 28 columns]

# %% [markdown]
# ### Rush Feature Eng

# %%
series = rush.rush_fantasy_pts

# %%
plot_acf(series)
plt.show()

plot_pacf(series)
plt.show()

# %%
cols = ['Yds', 'TD', 'FUM', '100yd_flag', 'rush_fantasy_pts']
lag3 = ['lag3_' + ''.join(x) for x in cols]
lag1 = ['lag1_' + ''.join(x) for x in cols]

# %%
rush[lag3] = move_avg(df = rush, smooth_col = cols, group_vals = 'Name', window= 3)
rush[lag1] = move_avg(df = rush, smooth_col = cols, group_vals = 'Name', window = 1)

# %%
rush.head()
# Out:
#                   Name Week Team     Opp     Score Att    Yds   Avg   TD  FUM  \
# 0          Marlon Mack    1  IND   @ LAC  L 24-30   25  174.0   7.0  1.0  0.0
# 1  Christian McCaffrey    1  CAR   vs LA  L 27-30   19  128.0   6.7  2.0  0.0
# 2       Saquon Barkley    1  NYG   @ DAL  L 17-35   11  120.0  10.9  0.0  0.0
# 3          Dalvin Cook    1  MIN  vs ATL  W 28-12   21  111.0   5.3  2.0  0.0
# 4          Mark Ingram    1  BAL   @ MIA  W 59-10   14  107.0   7.6  2.0  0.0
#
#    ... lag3_Yds  lag3_TD  lag3_FUM  lag3_100yd_flag  lag3_rush_fantasy_pts  \
# 0  ...    174.0      1.0       0.0              1.0                   23.4
# 1  ...    128.0      2.0       0.0              1.0                   24.8
# 2  ...    120.0      0.0       0.0              1.0                   12.0
# 3  ...    111.0      2.0       0.0              1.0                   23.1
# 4  ...    107.0      2.0       0.0              1.0                   22.7
#
#    lag1_Yds  lag1_TD  lag1_FUM  lag1_100yd_flag  lag1_rush_fantasy_pts
# 0     174.0      1.0       0.0              1.0                   23.4
# 1     128.0      2.0       0.0              1.0                   24.8
# 2     120.0      0.0       0.0              1.0                   12.0
# 3     111.0      2.0       0.0              1.0                   23.1
# 4     107.0      2.0       0.0              1.0                   22.7
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Receiving Feature Eng

# %%
cols = ['Yds', 'TD', 'FUM', '100yd_flag', 'rec_fantasy_pts']
lag3 = ['lag3_' + ''.join(x) for x in cols]
lag1 = ['lag1_' + ''.join(x) for x in cols]
series = rec.rec_fantasy_pts

# %%
plot_acf(series, lags = 20)
plt.show()

plot_pacf(series, lags = 15)
plt.show()

# %%
rec[lag3] = move_avg(df = rec, smooth_cols = cols, group_vals = 'Name', window = 3)
rec[lag1] = move_avg(df = rec, smooth_cols = cols, group_vals = 'Name', window = 1)
